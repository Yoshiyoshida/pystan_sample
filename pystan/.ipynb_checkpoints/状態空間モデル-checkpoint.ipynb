# %% [markdown]
# # 概要
# - 地球温暖化の予測
#
# ## データ
# - x:時間[年]
# - y:気温の相対値[度]
#
# ## 事前知識
# - 気温がある変化幅で推移している

# %% [markdown]
# # 状態空間モデルとは
#
# ## 前提知識
# - 時系列データは完全なランダムにしたがっていない
# - 何かしらの法則にしたがって変化している
# - 次の状態= 今の状態 + 法則性による変化
#
# ## 仮説
# - 気温はある法則で変化する
# -　測定した気温は正規分布している
#
# ## 統計モデル
# - μ[n] = μ[n-1] + ε[n]
# - ε[n] = Normal(0, σ)
# - y[n] = Normal(μ[n] , σ)

# %% [markdown]
# # 必要なライブラリのインストール

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy  
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

plt.style.use("ggplot")
import seaborn as sns

#import missingno as msno

#from tqdm import tqdm_notebook as tqdm

#import plotly
#plotly.offline.init_notebook_mode(connected=False)

import warnings
warnings.filterwarnings('ignore') # warningが出ないように設定
pd.set_option("display.max_rows", None) # pandasの表示上限をなくす
pd.set_option("display.max_columns", None) # pandasの表示上限をなくす

import pystan

# %% [markdown]
# # データの確認

# %%
df = pd.read_excel("../data/temperature_series.xlsx")

# %%
df.head()
# Out:
#       x       y
# 0  1891 -0.6291
# 1  1892 -0.7111
# 2  1893 -0.7520
# 3  1894 -0.7008
# 4  1895 -0.6752

# %%
len(df)
# Out:
# 121

# %%
plt.plot(df.x, df.y)

# %% [markdown]
# # モデルの定義

# %%
stan_model ="""  
data {
    int  T;
    int T_new;
    real Y[T];
}

parameters {
    real mu[T];
    real<lower=0> s_mu;
    real<lower=0> s_Y;
}
model {
    for (t in 2:T){
        mu[t] ~ normal(mu[t-1] , s_mu);
    }
    for (t in 1:T){
        Y[t] ~ normal(mu[t], s_Y);
    }
}

generated quantities{
    real mu_new;
    real Y_new[T+T_new];
    for (t in 1:T){
        Y_new[t] = normal_rng(mu[t], s_Y);
    }
    mu_new = normal_rng(mu[T], s_mu);
    Y_new[T+T_new] = normal_rng(mu_new, s_Y);
}
"""

# %%
 sm = pystan.StanModel(model_code= stan_model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_75b82786a5f47d50f3f19d8e860dba43 NOW.

# %%
stan_data = {"T":df.shape[0], "T_new":1, "Y":df.y }

# %%
fit = sm.sampling(data=stan_data,iter=2000, chains=3, warmup=1500, seed=123)

# %%
fit
# Out:
# WARNING:pystan:Truncated summary with the 'fit.__repr__' method. For the full summary use 'print(fit)'
# Warning: Shown data is truncated to 100 parameters
# For the full summary use 'print(fit)'
#
# Inference for Stan model: anon_model_75b82786a5f47d50f3f19d8e860dba43.
# 3 chains, each with iter=2000; warmup=1500; thin=1;
# post-warmup draws per chain=500, total post-warmup draws=1500.
#
#          mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# mu[81]  -0.36  4.6e-3   0.06  -0.47   -0.4  -0.36  -0.33  -0.26    148    1.0
# mu[82]  -0.26  2.1e-3   0.05  -0.35  -0.29  -0.26  -0.23  -0.17    455    1.0
# mu[83]  -0.24  1.2e-3   0.04  -0.32  -0.27  -0.24  -0.21  -0.16   1221   1.01
# mu[84]  -0.19  1.4e-3   0.04  -0.27  -0.22  -0.19  -0.16   -0.1   1008    1.0
# mu[85]  -0.15  1.8e-3   0.05  -0.25  -0.18  -0.15  -0.12  -0.06    654    1.0
# mu[86]  -0.14  2.2e-3   0.05  -0.23  -0.17  -0.14   -0.1  -0.05    495    1.0
# mu[87]  -0.16  1.5e-3   0.05  -0.25  -0.19  -0.16  -0.13  -0.07    929   1.01
# mu[88]  -0.14  2.5e-3   0.05  -0.24  -0.17  -0.14  -0.11  -0.05    341    1.0
# mu[89]  -0.19  2.0e-3   0.05  -0.28  -0.22  -0.19  -0.16   -0.1    547    1.0
# mu[90]  -0.19  3.3e-3   0.05  -0.29  -0.22  -0.19  -0.16  -0.09    228    1.0
# mu[91]  -0.14  1.3e-3   0.04  -0.23  -0.17  -0.14  -0.11  -0.06   1172    1.0
# mu[92]  -0.07  2.6e-3   0.05  -0.16   -0.1  -0.07  -0.04   0.02    328    1.0
# mu[93]  -0.05  1.6e-3   0.04  -0.14  -0.08  -0.05  -0.02   0.03    795    1.0
# mu[94]  -0.06  1.2e-3   0.04  -0.14  -0.09  -0.06  -0.03   0.03   1371    1.0
# mu[95]  -0.03  2.6e-3   0.05  -0.12  -0.06  -0.03 8.5e-3   0.06    333    1.0
# mu[96]  -0.05  1.4e-3   0.04  -0.14  -0.08  -0.05  -0.02   0.03   1023    1.0
# mu[97]   -0.1  3.6e-3   0.05   -0.2  -0.14   -0.1  -0.07-6.8e-3    188    1.0
# mu[98]   -0.1  2.9e-3   0.05  -0.19  -0.13   -0.1  -0.07-5.0e-3    262    1.0
# mu[99]  -0.06  1.3e-3   0.04  -0.15  -0.09  -0.06  -0.03   0.02   1008    1.0
# lp__    534.5    1.84  17.88 503.92 523.39 532.68 543.75 575.76     94   1.05
#
# Samples were drawn using NUTS at Mon Jan  7 18:13:11 2019.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fig = fit.plot()
# Out:
# WARNING:pystan:Deprecation warning. In future, use ArviZ library (`pip install arviz`)

# %%
Y_new_arr = fit.extract("Y_new")["Y_new"]

# %%
from scipy.stats import mstats
low_y50 , hight_y_50 = mstats.mquantiles(Y_new_arr, [0.25, 0.75], axis=0)
low_y95 , hight_y_95 =mstats.mquantiles(Y_new_arr, [0.025, 0.975], axis=0)

# %%
plt.plot(df.x, df.y)
x = df.x.values
x = np.append(x, 2017)
plt.fill_between(x, low_y50, hight_y_50,alpha=0.6, color="darkgray")
plt.fill_between(x, low_y95, hight_y_95,alpha=0.3, color="gray")
