# %% [markdown]
# # 概要
# - 空港の来客数の予測をpystanを使って行う

# %% [markdown]
# # 必要なライブラリのインポート

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy  
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

plt.style.use("ggplot")
import seaborn as sns

#import missingno as msno

#from tqdm import tqdm_notebook as tqdm

#import plotly
#plotly.offline.init_notebook_mode(connected=False)

import warnings
warnings.filterwarnings('ignore') # warningが出ないように設定
pd.set_option("display.max_rows", None) # pandasの表示上限をなくす
pd.set_option("display.max_columns", None) # pandasの表示上限をなくす

import pystan

# %% [markdown]
# # データを調べる

# %% [markdown]
# ## データのクレンジング
# - datetime型に直す

# %%
df = pd.read_csv("../data/AirPassengers.csv")

# %%
df.head()
# Out:
#   TravelDate  Passengers
# 0   1/1/1949         112
# 1   2/1/1949         118
# 2   3/1/1949         132
# 3   4/1/1949         129
# 4   5/1/1949         121

# %%
type(df.TravelDate)
# Out:
# pandas.core.series.Series

# %%
df.TravelDate = pd.to_datetime(df.TravelDate)

# %%
df.head()
# Out:
#   TravelDate  Passengers
# 0 1949-01-01         112
# 1 1949-02-01         118
# 2 1949-03-01         132
# 3 1949-04-01         129
# 4 1949-05-01         121

# %%
len(df)
# Out:
# 144

# %% [markdown]
# ## データの可視化

# %%
plt.plot(df.TravelDate, df.Passengers)

# %% [markdown]
# ## 学習と予測データの分離

# %%
train_num = int(len(df)*0.8)
print(train_num)
# Out:
# 115

# %%
df_train = df[:train_num]
df_test = df[train_num:]

# %% [markdown]
# # 統計的モデルの定義
# - μ[n] = μ[n-1] + ε[n]
# - ε[n] = Normal(0, σ)
# - y[n] = Normal(μ[n] , σ)
# と仮定する

# %% [markdown]
# ## モデルの定義

# %%
stan_model ="""  
data {
    int  T;
    int T_new;
    real Y[T];
}

parameters {
    real mu[T];
    real<lower=0> s_mu;
    real<lower=0> s_Y;
}
model {
    for (t in 2:T){
        mu[t] ~ normal(mu[t-1] , s_mu);
    }
    for (t in 1:T){
        Y[t] ~ normal(mu[t], s_Y);
    }
}

generated quantities{
    real mu_new;
    real Y_new[T+T_new];
    for (t in 1:T){
        Y_new[t] = normal_rng(mu[t], s_Y);
    }
    mu_new = normal_rng(mu[T], s_mu);
    Y_new[T+T_new] = normal_rng(mu_new, s_Y);
}
"""

# %% [markdown]
# ## モデルのコンパイル

# %%
sm = pystan.StanModel(model_code=stan_model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_75b82786a5f47d50f3f19d8e860dba43 NOW.

# %% [markdown]
# # データを定義

# %%
stan_data = {"T":df_train.shape[0], "T_new":1, "Y":df_train.Passengers}

# %% [markdown]
# # 観測

# %%
fit = sm.sampling(data=stan_data,iter=2000, chains=3, warmup=1500, seed=123)
# Out:
# WARNING:pystan:Rhat for parameter s_Y is 1.3124782224105487!
# WARNING:pystan:Rhat for parameter lp__ is 1.2860625489509951!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:12 of 1500 iterations saturated the maximum tree depth of 10 (0.8%)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.038513522082638696
# WARNING:pystan:Chain 2: E-BFMI = 0.01687983371729265
# WARNING:pystan:Chain 3: E-BFMI = 0.02749818089086852
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model

# %%
fit
# Out:
# WARNING:pystan:Truncated summary with the 'fit.__repr__' method. For the full summary use 'print(fit)'
# Warning: Shown data is truncated to 100 parameters
# For the full summary use 'print(fit)'
#
# Inference for Stan model: anon_model_75b82786a5f47d50f3f19d8e860dba43.
# 3 chains, each with iter=2000; warmup=1500; thin=1;
# post-warmup draws per chain=500, total post-warmup draws=1500.
#
#          mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# mu[1]  112.11    0.06   2.71 106.56  111.0 112.12 113.13  117.9   1892    1.0
# mu[2]  118.05    0.06   2.72  112.7 116.92 117.99 119.07 123.36   1986    1.0
# mu[3]  131.93    0.06   2.68 126.58 130.88 131.98 133.04 137.38   2130    1.0
# mu[4]  128.93    0.06   2.92 122.95 127.78 129.03 129.99 135.27   2384    1.0
# mu[5]   121.2    0.07   2.79  116.1 120.05 121.06 122.23 126.62   1464    1.0
# mu[6]  135.02    0.06   2.76 129.47 133.95 134.97 136.08 141.15   1978    1.0
# mu[7]  147.85    0.05    2.6 141.61 146.86 147.95  149.0 153.26   2514    1.0
# mu[8]  147.89    0.05   2.95  142.1  146.8 147.95 149.02 153.53   3066    1.0
# mu[9]  135.93    0.04   2.92 129.29 134.82 135.99 137.02  142.2   6326    1.0
# mu[10] 119.03    0.05   2.56  113.8  117.9 118.97 120.14 124.38   2681    1.0
# mu[11] 104.31    0.08   3.11   98.3 103.07 104.14  105.3 111.82   1579    1.0
# mu[12] 117.84    0.06   2.88 111.67 116.76 117.92 118.97 123.53   2698    1.0
# mu[13] 115.13    0.07   2.63 109.45 113.99 115.08  116.1 120.97   1260    1.0
# mu[14] 125.88    0.05   2.86 119.99 124.66 125.94 127.06 131.32   2881    1.0
# mu[15] 140.73    0.05   2.73 134.29 139.91 140.82 141.84 145.96   2792    1.0
# mu[16] 134.98    0.05   2.54 129.73  133.9 134.97 136.17 139.97   2474    1.0
# mu[17] 125.35    0.07   2.75 120.18 124.06 125.14 126.39 132.23   1602   1.01
# mu[18] 149.06    0.05   2.95 143.45 147.99 149.03  150.2 154.88   3151    1.0
# mu[19] 169.75    0.11   2.83 163.12 168.78 169.94 171.05 174.97    621   1.01
# mu[20] 169.93    0.05   2.57 164.34 168.81 169.94  171.1 175.38   3105    1.0
# mu[21] 157.85    0.05   2.67  151.9 156.87 157.89 158.99 163.22   3399    1.0
# mu[22] 133.07    0.06   2.55 127.72 131.91  133.0 134.09 139.05   1935    1.0
# mu[23] 114.41    0.17   2.64 109.65 113.04 114.19  115.5 120.33    248   1.02
# mu[24] 139.83    0.06   2.72 133.62 138.82 139.96 140.94 145.21   1889    1.0
# mu[86]  277.4    0.07   2.61 272.83  276.3 277.17 278.27 283.34   1361   1.01
# mu[87] 316.49    0.16   2.77 309.71 315.62 316.79 317.78 320.79    286   1.02
# mu[88] 312.99    0.05   2.58 307.19 311.94 312.96 314.04 318.41   2493    1.0
# mu[89] 318.49    0.16    2.7 314.31 317.15 318.17 319.44 325.28    270   1.02
# mu[90] 373.78     0.1   2.76 367.36 372.79 373.93 375.01 378.98    814   1.01
# mu[91] 412.48    0.18   2.94 405.09 411.54 412.82 413.77 417.72    275   1.02
# mu[92] 404.42    0.22   2.98 396.37 403.42 404.82 405.81 409.36    184   1.02
# mu[93] 355.05    0.05   2.57 349.91 353.99 355.01 356.01  360.9   2619    1.0
# mu[94] 306.12    0.06    2.8 300.35 305.08 306.06 307.04 312.16   1870    1.0
# mu[95] 271.71    0.31   2.89 267.01 270.35 271.29 272.49 278.52     88   1.04
# mu[96] 305.82    0.07   2.82 299.46  304.9 305.98 306.99 310.46   1828    1.0
# mu[97] 314.72    0.05   2.41 309.14 313.76 314.79 315.85 319.21   2145   1.01
# mu[98] 301.65    0.29   2.85 296.99 300.29 301.37  302.4 309.22     95   1.03
# mu[99] 355.39     0.3   2.86 347.99 354.49 355.77 356.73 360.01     93   1.03
# lp__   -551.6   19.46  71.72 -712.1 -598.0 -544.3 -492.8 -441.0     14   1.29
#
# Samples were drawn using NUTS at Mon Jan  7 19:25:38 2019.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fig = fit.plot()
# Out:
# WARNING:pystan:Deprecation warning. In future, use ArviZ library (`pip install arviz`)

# %%
Y_new_arr = fit.extract("Y_new")["Y_new"]

# %%
from scipy.stats import mstats
low_y50 , hight_y_50 = mstats.mquantiles(Y_new_arr, [0.25, 0.75], axis=0)
low_y95 , hight_y_95 =mstats.mquantiles(Y_new_arr, [0.025, 0.975], axis=0)

# %%
plt.plot(df.TravelDate, df.Passengers)
x = df_train.Passengers.values

plt.fill_between(x, low_y50, hight_y_50,alpha=0.6, color="darkgray")
plt.fill_between(x, low_y95, hight_y_95,alpha=0.3, color="gray")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-4b764180c139> in <module>()
#       2 x = df_train.Passengers.values
#       3
# ----> 4 plt.fill_between(x, low_y50, hight_y_50,alpha=0.6, color="darkgray")
#       5 plt.fill_between(x, low_y95, hight_y_95,alpha=0.3, color="gray")
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/matplotlib/pyplot.py in fill_between(x, y1, y2, where, interpolate, step, hold, data, **kwargs)
#    3052         ret = ax.fill_between(x, y1, y2=y2, where=where,
#    3053                               interpolate=interpolate, step=step, data=data,
# -> 3054                               **kwargs)
#    3055     finally:
#    3056         ax._hold = washold
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/matplotlib/axes/_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5090             where = True
#    5091         where = where & ~functools.reduce(np.logical_or,
# -> 5092                                           map(np.ma.getmask, [x, y1, y2]))
#    5093
#    5094         x, y1, y2 = np.broadcast_arrays(np.atleast_1d(x), y1, y2)
#
# ValueError: operands could not be broadcast together with shapes (115,) (116,)
